# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('./project2_전처리/fin_text_0_6763.csv') 
df = df[['DUNS_NO', 'CMP_NM', 'URL', 'EML', 'CONTACT_GRD_CD', 'ENG']]
df = df.fillna('')
df.head(3)
# Out:
#    DUNS_NO                      CMP_NM                                   URL  \
# 0  2444862     Garfield Preowned Autos  http://www.garfieldpreownedautos.com
# 1  3547571      R & R Auto Sales, Inc.         http://www.rrautosalesinc.com
# 2  3585643  Dorrance Auto Center, Inc.     http://www.dorranceautocenter.com
#
#                           EML CONTACT_GRD_CD  \
# 0  garfieldpreowned@gmail.com              B
# 1  rrautosalesinc@outlook.com              B
# 2        tonyd691@verizon.net              B
#
#                                                  ENG
# 0  ['garfield', 'autos', 'garfield', 'autos', 'pa...
# 1  ['savannah', 'hwy', 'jesup', 'ga', 'home', 'in...
# 2  ['thank', 'business', 'car', 'repair', 'servic...

# %%
# 한글 및 영어 텍스트를 문자열로 변경 + 쉼표 전처리 함수 지정
def to_string(text): # 리스트에서 문자열로 다 바꿔주기 
    text = str(text)
    text=text.replace("'","")
    text=text.replace("[","")
    text=text.replace("]","") 
    return text

# %%
df['ENG'] = [to_string(strings) for strings in df['ENG']]ㅇ

# %%
# 영어 키워드 
keywords_eng = pd.read_csv('keywordList.csv')
display(keywords_eng.head(5))
keywords_eng.columns = ['eng_keywords'] # 영어 키워드  # 컬럼이름 변경
# Out:
#   SETTED_KEYWORDS
# 0  Electronically
# 1          Sensor
# 2            Fuel
# 3        Subframe
# 4         Angular

# %% [markdown]
# # 첫번째 카운트 벡터
# 1) 자동차 키워드 리스트 학습을 시키고
# 2) 각 url 별로 자동차 키워드 나온 횟수 카운팅
# 3) 각 url 별로 키워드 30개씩 자즘 , 나머지는 다 제외시키고
# 4) 그 키워드가 나온 횟수만큼 다시 url에 넣어줌

# %%
# 영어 버전 
from sklearn.feature_extraction.text import CountVectorizer
# CountVectAttributeErrororizer 인스턴스 생성 (희소 행렬 표현 사용)
cv_e = CountVectorizer()

# fit 메서드로 영어 키워드 사전 학습
fit_eng = cv_e.fit(keywords_eng['eng_keywords']) # 주어진 영어키워드 학습 340여개 되는 거
# 영어 버전
sparse_matrix_e = cv_e.transform(df['ENG']) # 위에서 학습한 키워드를 토대로 카운팅!한 키워드 리스트 / 각 어휘사전에 나온  단어 카운팅 
# 희소 행렬을 데이터프레임으로 변환
dense_matrix = pd.DataFrame(sparse_matrix_e.toarray(), columns=cv_e.get_feature_names_out()) # 데이터 프레임으로 저장

# index명 추가
dense_matrix.index = df['URL']
origin_dense_matrix_e = dense_matrix_e

# 카운트 벡터라이즈를 통함 url별 키워드 구축 
def url_keywords(dense_matrix):
    outside = []
    for i in range(len(dense_matrix)):
        top_keys = dense_matrix.iloc[i][dense_matrix.iloc[i] != 0].sort_values(ascending=False)[:30] 
        #특정 행에서 0이 아닌 값들을 선택한 후, 내림차순으로 정렬하여 상위 30개 값을 선택하는 연산
        inside = []
        k = 0
        for k in range(len(top_keys)): # 키워드 갯수만큼 돌기 -> 30개 이하도 있을 수 있음
            count = top_keys.iloc[k]
            product = top_keys.index[k]
            
            j = 0
            for j in range(count): # 갯수 만큼 다시 넣어주기 
                inside.append(product)
        outside.append(inside) # 한행이 끝나면 
    frame = pd.DataFrame({"Keywords": outside},index = df['URL'])
    return frame
frame = pd.DataFrame()
frame['keywords_eng']= url_keywords(dense_matrix) # 함수 사용해서 urlㅠ별 키워드 상위 30개 다시 추출 
frame['keywords_eng']=[to_string(strings) for strings in frame['keywords_eng']] # 각 리스트를 문자열로 반환

# %% [markdown]
# # 두번째 카운트 벡터

# %%
# 영어버전 - 카운트 벡터 
from sklearn.feature_extraction.text import CountVectorizer
re_cv_e = CountVectorizer()
re_cv_e.fit(frame['keywords_eng']) 
sparse_matrix_e =re_cv_e.transform(frame['keywords_eng'])

# 희소 행렬을 데이터프레임으로 변환
dense_matrix = pd.DataFrame(sparse_matrix_e.toarray(), columns=re_cv_e.get_feature_names_out())

# index명 추가
dense_matrix.index = frame.index

# 데이터프레임 출력
display(dense_matrix.head(3))
# Out:
#                                       abs  absorber  ac  actuator  adaptive  \
# URL
# http://www.garfieldpreownedautos.com    0         0   0         0         0
# http://www.rrautosalesinc.com           0         0   0         0         0
# http://www.dorranceautocenter.com       0         0   0         0         0
#
#                                       adjuster  air  airbag  alternator  \
# URL
# http://www.garfieldpreownedautos.com         0    0       0           0
# http://www.rrautosalesinc.com                0   35      34           0
# http://www.dorranceautocenter.com            0    0       0           0
#
#                                       angular  ...  ventilator  visor  \
# URL                                            ...
# http://www.garfieldpreownedautos.com        0  ...           0      0
# http://www.rrautosalesinc.com               0  ...           0      0
# http://www.dorranceautocenter.com           0  ...           0      0
#
#                                       washcoat  washer  water  weatherstrip  \
# URL
# http://www.garfieldpreownedautos.com         0       0      0             0
# http://www.rrautosalesinc.com                0       0      0             0
# http://www.dorranceautocenter.com            0       0      0             0
#
#                                       wheel  window  wiper  wiring
# URL
# http://www.garfieldpreownedautos.com      0       0      0       0
# http://www.rrautosalesinc.com            83       0      0       0
# http://www.dorranceautocenter.com         3       0      0       0
#
# [3 rows x 320 columns]

# %%
import pickle

# 저장할 파일 경로
pickle_file_path = "re_cv_e.pickle"

# re_cv_e 객체를 피클 파일로 저장
with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(re_cv_e, pickle_file,pickle.HIGHEST_PROTOCOL)

print("re_cv_e를 피클 파일로 저장했습니다.")
# Out:
# re_cv_e를 피클 파일로 저장했습니다.

# %%
import pickle

pickle_file_path = "/Users/kimmirae/Desktop/DIMA3/2project/re_cv_e.pickle"

# 파일을 바이너리 모드로 열고 pickle 객체를 직접 로드
with open(pickle_file_path, 'rb') as pickle_file:
    #re_cv_e_loaded = pickle.load(pickle_file)
    re_cv_e = pickle.load(pickle_file)

# %%
# 저장된 피클 파일을 로드하여 dense_matrix_e 데이터프레임 복원
pickle_file_path = "dense_matrix.pickle"
with open(pickle_file_path, 'rb') as pickle_file:
    dense_matrix = pickle.load(pickle_file)

# %%
# df를 피클로 저장 

#피클 파일로 저장하기 

import pickle

# 저장할 파일 경로
pickle_file_path = "dataframe.pickle"

# dense_matrix_e 데이터프레임을 피클 파일로 저장
with open(pickle_file_path, 'wb') as pickle_file:
    pickle.dump(df, pickle_file,pickle.HIGHEST_PROTOCOL)

print("df를 피클 파일로 저장했습니다.")

# %%
pickle_file_path = "dataframe.pickle"
with open(pickle_file_path, 'rb') as pickle_file:
    df = pickle.load(pickle_file)

# %%
dense_matrix
# Out:
#                                       abs  absorber  ac  actuator  adaptive  \
# URL
# http://www.garfieldpreownedautos.com    0         0   0         0         0
# http://www.rrautosalesinc.com           0         0   0         0         0
# http://www.dorranceautocenter.com       0         0   0         0         0
# http://www.bendix.com                  16         0   0         0         0
# http://www.emmr.org                     0         0   0         0         0
# ...                                   ...       ...  ..       ...       ...
# http://www.sjrafferty.com               0         0   1         0         0
# http://www.ktrmotors.com.br             0         0   0         0         0
# http://www.alycosrl.com.ar              0         0   0         0         0
# http://www.motorhomescheid.com.br       0         0   0         0         0
# http://www.pongolini.com                0         0   0         0         0
#
#                                       adjuster  air  airbag  alternator  \
# URL
# http://www.garfieldpreownedautos.com         0    0       0           0
# http://www.rrautosalesinc.com                0   35      34           0
# http://www.dorranceautocenter.com            0    0       0           0
# http://www.bendix.com                        0   97       0           0
# http://www.emmr.org                          0    0       0           0
# ...                                        ...  ...     ...         ...
# http://www.sjrafferty.com                    0   35       0           0
# http://www.ktrmotors.com.br                  0    0       0           0
# http://www.alycosrl.com.ar                   0    0       0           0
# http://www.motorhomescheid.com.br            0    0       0           0
# http://www.pongolini.com                     0    0       0           0
#
#                                       angular  ...  ventilator  visor  \
# URL                                            ...
# http://www.garfieldpreownedautos.com        0  ...           0      0
# http://www.rrautosalesinc.com               0  ...           0      0
# http://www.dorranceautocenter.com           0  ...           0      0
# http://www.bendix.com                       0  ...           0      0
# http://www.emmr.org                         0  ...           0      0
# ...                                       ...  ...         ...    ...
# http://www.sjrafferty.com                   0  ...           0      0
# http://www.ktrmotors.com.br                 0  ...           0      0
# http://www.alycosrl.com.ar                  0  ...           0      0
# http://www.motorhomescheid.com.br           0  ...           0      0
# http://www.pongolini.com                    0  ...           0      0
#
#                                       washcoat  washer  water  weatherstrip  \
# URL
# http://www.garfieldpreownedautos.com         0       0      0             0
# http://www.rrautosalesinc.com                0       0      0             0
# http://www.dorranceautocenter.com            0       0      0             0
# http://www.bendix.com                        0       0      0             0
# http://www.emmr.org                          0       0      0             0
# ...                                        ...     ...    ...           ...
# http://www.sjrafferty.com                    0       0      2             0
# http://www.ktrmotors.com.br                  0       0      0             0
# http://www.alycosrl.com.ar                   0       0      0             0
# http://www.motorhomescheid.com.br            0       0      0             0
# http://www.pongolini.com                     0       0      0             0
#
#                                       wheel  window  wiper  wiring
# URL
# http://www.garfieldpreownedautos.com      0       0      0       0
# http://www.rrautosalesinc.com            83       0      0       0
# http://www.dorranceautocenter.com         3       0      0       0
# http://www.bendix.com                     5       0      0       0
# http://www.emmr.org                       0       0      0       0
# ...                                     ...     ...    ...     ...
# http://www.sjrafferty.com                 0       0      0       0
# http://www.ktrmotors.com.br               0       0      0       0
# http://www.alycosrl.com.ar                0       0      0       0
# http://www.motorhomescheid.com.br         0       0      0       0
# http://www.pongolini.com                  0       0      0       0
#
# [5269 rows x 320 columns]

# %% [markdown]
# # 피클 파일 불러오기 , 결과값 출력하기

# %%
import pickle

# 1. 카운트 벡터라이즈 모댈 불러오기 
pickle_file_path = "re_cv_e.pickle"
with open(pickle_file_path, 'rb') as pickle_file:
    #re_cv_e_loaded = pickle.load(pickle_file)
    re_cv_e = pickle.load(pickle_file)

# 2. 회사 크롤링 데이터 불러오기 
pickle_file_path = "dataframe.pickle"
with open(pickle_file_path, 'rb') as pickle_file:
    df = pickle.load(pickle_file)

# 3. 각 회사별 키워트 카운트한 데이터 프레임 불러오기 
pickle_file_path = "dense_matrix.pickle"
with open(pickle_file_path, 'rb') as pickle_file:
    dense_matrix = pickle.load(pickle_file)

# %%
from nltk import word_tokenize
from nltk import sent_tokenize
from nltk import pos_tag
import nltk
import re
from nltk import WordNetLemmatizer
from konlpy.tag import Mecab
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

wlem = nltk.WordNetLemmatizer()
tokenizer = Mecab().morphs

# 한글 및 영어 텍스트를 문자열로 변경 + 쉼표 전처리 함수 지정
def to_string(text): # 리스트에서 문자열로 다 바꿔주기 
    text = str(text)
    text=text.replace("'","")
    text=text.replace("[","")
    text=text.replace("]","") 
    return text

def calculate_similarity(input_vector, df_vectors):
    similarity = cosine_similarity(input_vector, df_vectors)
    return similarity[0]

def inputKeyword(input_keyword):
    input_keyword = input_keyword.lower() # 리스트-> 문자열로 바꿈 

    # 불용어 제거 및 단어만 추출 
    stopwords = nltk.corpus.stopwords.words('english') # 영어 불용어 
    all_tokens = []
    
    word_tokens = word_tokenize(input_keyword) # 단어로 토큰화 -> 리스트로 반환

    for word in word_tokens:
        if len(word) != 1: # 글자수 1이상만 출력 
            if word not in stopwords: # 불용어를 포함하지 않는다면 그대로 추가하기
                all_tokens.append(word)
    
    #stopword 제거
    english_return = []
    tagged_sentence = pos_tag(all_tokens) # 명사로 바꿔주려고

    for i in range(len(tagged_sentence)):
        if tagged_sentence[i][1].startswith('N'): # 명사형
            new_word = wlem.lemmatize(tagged_sentence[i][0])   #명사의 원형으로 바꿔서 넣어주기    
            english_return.append(new_word)
            
    input_keyword = english_return
    
    count = 0
    search_keyword = []
    
    for word in input_keyword:
        if word in re_cv_e.get_feature_names_out(): # 입력한 키워드가 없다면 품목리스트에 없을 경우 대비 
            search_keyword.append(word)
            count +=1
        else:
            continue
    if count == 0: # 입력한 키워드가 품목리스트에 하나도 없음  
        print('입력하신 키워드는 품목리스트에 없습니다. 다시 입력해주세요')
        return -1;
        
    else: # 입력한 키워드가 품목리스트에 있다면 
        print(f'"{str(search_keyword)[2:-2]}" 취급하는 회사 url에 대한 검색')
        print('\n')
        input_keyword = to_string(input_keyword) # 문자열로 바꿔주는 작업
        buyer = pd.DataFrame([input_keyword], columns=['order'])
        buyer1 = re_cv_e.transform(buyer['order'])
        dense = pd.DataFrame(buyer1.toarray(), columns=re_cv_e.get_feature_names_out())
        #display(dense)
        #alldense_matrix = dense_matrix # 
        columns_index =  dense_matrix.index
        #break

        ## 코사인 유사도 구함 
        similarity  = calculate_similarity(dense,dense_matrix) #사용자 입력과 각 url별과 코사인 유사도 구하기
        df_similarity = pd.DataFrame({'url': columns_index, 'similarity': similarity})
        
        top_15 = df_similarity.sort_values(by='similarity', ascending=False).head(15)
        if top_15.iloc[0]['similarity'] == 0.0:
            print(f'검색하신 키워드를 취급하는 회사는 존재하지 않습니다.')
            return -1;
        index_list = []
        for i in range(len(top_15)):  
            url = top_15.iloc[i]['url']
            index_list.append(df[df['URL'] == url].index[0]) #인덱스 값만 가지고 옴 
        
        last_answer = df.iloc[index_list]
        
        index_name = []
        for num in range(len(last_answer)):
            index_name.append(f'{num+1}위')
        last_answer.index= index_name
        return last_answer

# %%
result=inputKeyword("vehicle")
result
# Out:
# "vehicle" 취급하는 회사 url에 대한 검색
#        DUNS_NO                             CMP_NM  \
# 1위   201675787       Lakehead Motors Limited, The
# 2위   435533658               FRATELLI BORDONI SRL
# 3위   230265443               CLASSIC INVESTOR LTD
# 4위   249483991              Shurco Properties Ltd
# 5위   223444500         PREMIER VEHICLE CO LIMITED
# 6위   201829268                Kelligrews Automart
# 7위   226903879                Sure Vehicle Centre
# 8위   233576508       STANFORD COACH WORKS LIMITED
# 9위   225966866                    AXIS DEALER LTD
# 10위  569881519  SHOREHAM VEHICLE AUCTIONS LIMITED
# 11위  687988485                    Aptiv Korea LLC
# 12위  227927141           BECTEC VEHICLE SALES LTD
# 13위  229406354     Volkswagen Commercial Vehicles
# 14위  299315457     LARCHTOWER ENGINEERING LIMITED
# 15위  222119590        KNIGHTSBRIDGECARSNI LIMITED
#
#                                           URL  \
# 1위               http://www.lakeheadmotors.ca
# 2위             http://www.fratellibordoni.com
# 3위           http://www.classicinvestor.co.uk
# 4위            http://www.fourseasonssales.com
# 5위   http://www.premiervehicletransport.co.uk
# 6위          http://www.kelligrewsautomart.com
# 7위                www.surevehiclecentre.co.uk
# 8위               www.stanfordcoachworks.co.uk
# 9위    http://www.axisvehicleremarketing.co.uk
# 10위    http://www.shorehamvehicleauctions.com
# 11위                      http://www.aptiv.com
# 12위                          www.bectec.co.uk
# 13위                 www.volkswagen-vans.co.uk
# 14위          http://www.forgemotorsport.co.uk
# 15위      http://www.knightsbridgecarsni.co.uk
#
#                                                    EML CONTACT_GRD_CD  \
# 1위                      rcristoforo@lakeheadmotors.com              B
# 2위                           sales@fratellibordoni.com              B
# 3위                         sales@classicinvestor.co.uk              B
# 4위                         lemmerson@rvfourseasons.com              B
# 5위   Kingdom07857426612premiervehicletransport@hotm...              B
# 6위                                    name@example.com              B
# 7위                         surevehiclecentre@gmail.com              B
# 8위                      parts@stanfordcoachworks.co.uk              B
# 9위                              hello@axisdealer.co.uk              B
# 10위                   gdpr@shorehamvehicleauctions.com              B
# 11위                                     mail@aptiv.com              B
# 12위                       hgv@bectecvehiclerepairs.com              B
# 13위                     existingevoffer@octoenergy.com              B
# 14위                             store@avontuning.co.uk              B
# 15위                    knightsbridgecarsni@outlook.com              B
#
#                                                    ENG
# 1위   contact, location, vehicle, condition, year, m...
# 2위   ampia, gamma, di, personalizzazioni, soddisfar...
# 3위   team, vehicle, peace, vehicle, buyers, vehicle...
# 4위   seasons, sales, seasons, sales, navigation, se...
# 5위   premier, vehicle, transport, services, home, p...
# 6위   skip, menu, skip, content, skip, footer, auto,...
# 7위   home, mot, garage, services, quality, cars, mo...
# 8위   stanford, converters, wheelchair, minibuses, s...
# 9위   home, buying, selling, buy, sell, trade, quali...
# 10위  shoreham, vehicle, auctions, cookies, experien...
# 11위  browser, support, element, aptiv, ces, play, p...
# 12위  days, week, services, gallery, family, vehicle...
# 13위  uses, cookies, others, experience, personalise...
# 14위  cookie, settings, cookies, browse, party, cook...
# 15위  uses, cookies, site, privacy, policy, moira, r...

# %%
result

# %%
json_result = result.to_json(orient="records")
